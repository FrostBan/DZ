# %%
surname = input('Введіть ваше призвіще')
mark = int(input('Введіть вашу оцінку'))
if b < 75:
    if b < 60:
        print(f'{surname} набрав {mark} балів тому оцінка - незадовільно')
    else:
        print(f'{surname} набрав {mark} балів тому оцінка - задовільно')
else:
    if b >= 95:
        print(f'{surname} набрав {mark} балів тому оцінка - відмінно')
    else:
        print(f'{surname} набрав {mark} балів тому оцінка - добре')

# %%
city = input('Введіть перші дві літери номерного знаку:')

match city:
    case 'АА' | "КА":
        print("Київ")
    case 'АВ':
        print("Вінницька область")
    case 'АЕ':
        print("Дніпропетровська область")
    case 'АН':
        print("Донецька область")
    case _:
        print('Інша область')
